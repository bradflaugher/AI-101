# %% [markdown]
# # Train first model

# %% [markdown]
# Training base model based on AlexNet architecture implemented in this kaggle notebook:
# <br>
# https://www.kaggle.com/vortexkol/alexnet-cnn-architecture-on-tensorflow-beginner

# %% [markdown]
# ## Setup

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras import layers

# Plotting pretty figures and avoid blurry images
# %config InlineBackend.figure_format = 'retina'

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print('Error')
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# ### Utils

# %%
def display_car_price(X, y, y_pred=None):
    num_images = 28
    
    plt.figure(figsize=(20, 10))
    for i, (img, price) in enumerate(zip(X[:num_images], y[:num_images])):
        ax = plt.subplot(4, 7, i + 1)    
        ax.imshow(img[:, :, 0], cmap='gray')
        if y_pred is not None:
            ax.set_title(f'{price} | {int(y_pred[i][0])}')
        else:
            ax.set_title(price)
        ax.axis('off')

# %% [markdown]
# ### Load data

# %%
data_path = '../datasets/autoria/ready/image_price_128_gray_int_100k.npz'
data = np.load(data_path)

# %%
data.files
# Out:
# ['X', 'y']

# %%
X = data['X']
y = data['y']

# All data don't fit into memory when converted to float
X = X[:50_000]
y = y[:50_000]

X.shape, y.shape
# Out:
# ((50000, 128, 128, 1), (50000,))

# %%
X.dtype
# Out:
# dtype('uint8')

# %% [markdown]
# ### Train-Validation split

# %%
# 80% for validation
train_pct = 0.8
split_point = int(X.shape[0] * train_pct)
split_point
# Out:
# 40000

# %%
X_train = X[:split_point]
X_val   = X[split_point:]

y_train = y[:split_point]
y_val   = y[split_point:]

# free up memory
del X
del y

# %%
# normalize data
X_train = X_train.astype('float32') / 255
X_val = X_val.astype('float32') / 255

# %%
X_train.shape, y_train.shape
# Out:
# ((40000, 128, 128, 1), (40000,))

# %%
X_val.shape, y_val.shape
# Out:
# ((10000, 128, 128, 1), (10000,))

# %%
display_car_price(X_train, y_train)

# %% [markdown]
# ### Model Setup

# %%
# (128, 128, 1)
input_shape = X_train.shape[1:]

def get_model():
    model = keras.Sequential([
        layers.Conv2D(filters=128, kernel_size=(11,11), strides=(4,4), activation='relu', input_shape=input_shape),
        layers.BatchNormalization(),
        layers.MaxPool2D(pool_size=(2,2)),

        layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', padding="same"),
        layers.BatchNormalization(),
        layers.MaxPool2D(pool_size=(3,3)),

        layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
        layers.BatchNormalization(),

        layers.Conv2D(filters=256, kernel_size=(1,1), strides=(1,1), activation='relu', padding="same"),
        layers.BatchNormalization(),

        layers.Conv2D(filters=256, kernel_size=(1,1), strides=(1,1), activation='relu', padding="same"),
        layers.BatchNormalization(),
        layers.MaxPool2D(pool_size=(2,2)),

        layers.Flatten(),
        layers.Dense(1024,activation='relu'),
        layers.Dropout(0.3),

        layers.Dense(1024,activation='relu'),
        layers.Dropout(0.4),

        layers.Dense(10,activation='relu'),
        layers.Dense(1,activation='relu'),
    ])
        
    model.compile(optimizer='adam', 
                  loss=keras.losses.mape, 
                  metrics=[
                      keras.metrics.mean_squared_error,
                      keras.metrics.mean_absolute_error,
                      keras.metrics.mean_absolute_percentage_error
                  ])
    
    return model

# %%
model = get_model()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 128)       15616
# _________________________________________________________________
# batch_normalization (BatchNo (None, 30, 30, 128)       512
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 128)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 15, 15, 256)       819456
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 15, 15, 256)       1024
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 5, 5, 256)         590080
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 5, 5, 256)         1024
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 5, 5, 256)         65792
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 5, 5, 256)         1024
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 5, 5, 256)         65792
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 5, 5, 256)         1024
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1049600
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                10250
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 3,670,805
# Trainable params: 3,668,501
# Non-trainable params: 2,304
# _________________________________________________________________

# %% [markdown]
# ### Train model

# %%
history = model.fit(X_train, y_train, 
                    batch_size=128, 
                    epochs=30, 
                    validation_data=(X_val, y_val))
# Out:
# Epoch 1/30
# 313/313 [==============================] -
# Epoch 19/30
# 313/313 [==============================] - 16s 50ms/step - loss: 19.9343 - mean_squared_error: 175802690.3949 - mean_absolute_error: 3450.8824 - mean_absolute_percentage_error: 19.9343 - val_loss: 46.0431 - val_mean_squared_error: 278086272.0000 - val_mean_absolute_error: 6431.5791 - val_mean_absolute_percentage_error: 46.0431
# Epoch 20/30
# 313/313 [==============================] - 16s 50ms/step - loss: 19.1407 - mean_squared_error: 132691534.7516 - mean_absolute_error: 3244.2831 - mean_absolute_percentage_error: 19.1407 - val_loss: 51.4850 - val_mean_squared_error: 242681696.0000 - val_mean_absolute_error: 5740.8862 - val_mean_absolute_percentage_error: 51.4850
# Epoch 21/30
# 313/313 [==============================] - 16s 50ms/step - loss: 18.6367 - mean_squared_error: 122442065.4777 - mean_absolute_error: 3157.8063 - mean_absolute_percentage_error: 18.6367 - val_loss: 55.8108 - val_mean_squared_error: 236508576.0000 - val_mean_absolute_error: 5747.7866 - val_mean_absolute_percentage_error: 55.8108
# Epoch 22/30
# 313/313 [==============================] - 16s 51ms/step - loss: 17.9036 - mean_squared_error: 162728459.8726 - mean_absolute_error: 3241.4433 - mean_absolute_percentage_error: 17.9036 - val_loss: 48.8990 - val_mean_squared_error: 247618624.0000 - val_mean_absolute_error: 5828.9746 - val_mean_absolute_percentage_error: 48.899024 - mean_squared_er - ETA: 0s - loss: 17.8983 - mean_squared_error: 162960593.3981 - mean_absolute_error: 3242.3936 - mean_absolute_percentage_error: 1
# Epoch 23/30
# 313/313 [==============================] - 16s 51ms/step - loss: 18.0600 - mean_squared_error: 140136771.2102 - mean_absolute_error: 3101.7339 - mean_absolute_percentage_error: 18.0600 - val_loss: 51.7765 - val_mean_squared_error: 240466192.0000 - val_mean_absolute_error: 5706.1841 - val_mean_absolute_percentage_error: 51.7765
# Epoch 24/30
# 313/313 [==============================] - 16s 51ms/step - loss: 17.2143 - mean_squared_error: 154835829.1911 - mean_absolute_error: 3107.9526 - mean_absolute_percentage_error: 17.2143 - val_loss: 49.9298 - val_mean_squared_error: 250295280.0000 - val_mean_absolute_error: 5807.3794 - val_mean_absolute_percentage_error: 49.9298
# Epoch 25/30
# 313/313 [==============================] - 16s 52ms/step - loss: 16.8462 - mean_squared_error: 145746154.9299 - mean_absolute_error: 2986.5981 - mean_absolute_percentage_error: 16.8462 - val_loss: 47.5955 - val_mean_squared_error: 251407104.0000 - val_mean_absolute_error: 5817.8550 - val_mean_absolute_percentage_error: 47.5955
# Epoch 26/30
# 313/313 [==============================] - 16s 51ms/step - loss: 16.8185 - mean_squared_error: 150870235.6688 - mean_absolute_error: 2991.5935 - mean_absolute_percentage_error: 16.8185 - val_loss: 47.6402 - val_mean_squared_error: 244762464.0000 - val_mean_absolute_error: 5756.1890 - val_mean_absolute_percentage_error: 47.6402
# Epoch 27/30
# 313/313 [==============================] - 16s 51ms/step - loss: 16.2208 - mean_squared_error: 132262400.9682 - mean_absolute_error: 2900.7349 - mean_absolute_percentage_error: 16.2208 - val_loss: 56.3343 - val_mean_squared_error: 229808768.0000 - val_mean_absolute_error: 5724.9248 - val_mean_absolute_percentage_error: 56.3343
# Epoch 28/30
# 313/313 [==============================] - 16s 50ms/step - loss: 15.8615 - mean_squared_error: 140786276.2293 - mean_absolute_error: 2837.3080 - mean_absolute_percentage_error: 15.8615 - val_loss: 50.0093 - val_mean_squared_error: 244038288.0000 - val_mean_absolute_error: 5724.6089 - val_mean_absolute_percentage_error: 50.0093
# Epoch 29/30
# 313/313 [==============================] - 16s 51ms/step - loss: 15.5148 - mean_squared_error: 120292776.9124 - mean_absolute_error: 2690.6571 - mean_absolute_percentage_error: 15.5148 - val_loss: 50.0409 - val_mean_squared_error: 239678368.0000 - val_mean_absolute_error: 5703.5503 - val_mean_absolute_percentage_error: 50.0409
# Epoch 30/30
# 313/313 [==============================] - 16s 51ms/step - loss: 15.3083 - mean_squared_error: 146521351.0064 - mean_absolute_error: 2781.1457 - mean_absolute_percentage_error: 15.3083 - val_loss: 50.4015 - val_mean_squared_error: 239773520.0000 - val_mean_absolute_error: 5705.7666 - val_mean_absolute_percentage_error: 50.4015

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'mean_squared_error', 'mean_absolute_error', 'mean_absolute_percentage_error', 'val_loss', 'val_mean_squared_error', 'val_mean_absolute_error', 'val_mean_absolute_percentage_error'])

# %%
history_dict = history.history
mape_values = history_dict['mean_absolute_percentage_error']
val_mape_values = history_dict['val_mean_absolute_percentage_error']

plt.plot(epochs, mape_values, 'bo', label='Training mape')
plt.plot(epochs, val_mape_values, 'b', label='Validation mape')
plt.title('Training and validation mean_absolute_percentage_error')
plt.xlabel('Epochs')
plt.ylabel('MAPE')
plt.legend()
plt.show()

# %%
history_dict = history.history
mse_values = history_dict['mean_squared_error']
val_mse_values = history_dict['val_mean_squared_error']

plt.plot(epochs, mse_values, 'bo', label='Training mse')
plt.plot(epochs, val_mse_values, 'b', label='Validation mse')
plt.title('Training and validation mean_squared_error')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()
plt.show()

# %%
history_dict = history.history
mae_values = history_dict['mean_absolute_error']
val_mae_values = history_dict['val_mean_absolute_error']

plt.plot(epochs, mae_values, 'bo', label='Training mae')
plt.plot(epochs, val_mae_values, 'b', label='Validation mae')
plt.title('Training and validation mean_absolute_error')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.show()

# %%
y_pred = model.predict(X_val)

# %%
display_car_price(X_val, y_val, y_pred)
# true price | predicted price

# %% [markdown]
# ### Saving model

# %%
model_path = 'models/0/'

# %%
model.save(model_path)
# Out:
# INFO:tensorflow:Assets written to: models/0/assets

# %% [markdown]
# **Loading saved model**

# %%
saved_model = tf.keras.models.load_model(model_path)

# %%
test_car = np.expand_dims(X_val[1], 0)
test_car.shape
# Out:
# (1, 128, 128, 1)

# %%
saved_model.predict(test_car)
# Out:
# array([[7731.2046]], dtype=float32)

# %%
y_val[1]
# Out:
# 8200
